# %% [markdown]
# <a href="https://colab.research.google.com/github/Lio72rga/Aprendizaje_Automatico-2026/blob/main/Aprend_Aut_Clase2_Lionel_Martinez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introducciòn**
# En esta actividad se aborda la adquisición de datos utilizando la librería Pandas en Python. Esta herramienta es fundamental en el campo del Aprendizaje Automático, ya que permite importar, manipular y analizar datos provenientes de diferentes fuentes y formatos.
# En este caso, se trabajó con tres tipos de archivos: CSV, JSON y Excel, los cuales contienen información sobre ventas, clientes e inventario respectivamente.

# %% [markdown]
# **Descomprimir archivos zip**

# %%
import zipfile

with zipfile.ZipFile("/content/archivos semana 2.zip", 'r') as zip_ref:
    zip_ref.extractall("datos")

# %% [markdown]
# **Importar**

# %%
import os
import pandas as pd
import zipfile

# %% [markdown]
# **Verificar si se importaron los archivos de la carpeta**

# %%
import os

# %%
os.listdir("datos")
# Out:
# ['ventas (1).csv', 'inventario.xlsx', 'clientes.json']

# %% [markdown]
# **Carga de datos**

# %%
import pandas as pd

# Cargar datos de ventas
ventas_df = pd.read_csv('datos/ventas (1).csv')

# Cargar datos de clientes
clientes_df = pd.read_json('datos/clientes.json')

# Cargar datos de inventario
inventario_df = pd.read_excel('datos/inventario.xlsx')

# %% [markdown]
# **Verifico los archivos importados**

# %%
ventas_df.head()
clientes_df.head()
inventario_df.head()
# Out:
#    id_producto    nombre    categoria  stock  precio
# 0            1  Notebook  Electrónica     10    1200
# 1            2     Mouse   Accesorios     50      25
# 2            3   Teclado   Accesorios     30      45
# 3            4   Monitor  Electrónica     15     300

# %% [markdown]
# **Metricas**

# %%
# Cantidad total de clientes
print("Cantidad total de clientes:", len(clientes_df))

# Promedio de stock
promedio_stock = inventario_df["stock"].mean()
print("El stock promedio es:", promedio_stock)
# Out:
# Cantidad total de clientes: 3
# El stock promedio es: 26.25

# %% [markdown]
# **Explicacion**
# ##  Integración de datos
#
# Se intentó integrar los datos de ventas y clientes mediante la función `merge()` de Pandas.
#
# Sin embargo, no fue posible realizar la combinación de los DataFrames debido a que no existe una columna en común entre ambos conjuntos de datos.
#
# El DataFrame de ventas contiene la columna "id_venta", mientras que el de clientes contiene "id_cliente", sin una relación directa entre ellos.
#
# Por este motivo, no se pudo realizar la integración de datos en este caso.

# %% [markdown]
# ## Conclusión
#
# En esta actividad se logró:
#
# - Importar datos desde distintos formatos (CSV, JSON y Excel).
# - Explorar los datos utilizando funciones básicas de Pandas.
# - Obtener información relevante como la cantidad de clientes y el promedio de stock.
# - Comprender la importancia de integrar datos de múltiples fuentes.
#
# El uso de Pandas permite trabajar de manera eficiente con grandes volúmenes de datos, siendo una herramienta fundamental en el desarrollo de proyectos de Aprendizaje Automático.
